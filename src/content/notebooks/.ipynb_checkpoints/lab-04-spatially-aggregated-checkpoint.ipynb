# %% [markdown]
# # Lab 4: Spatially Aggregated Analysis

# %%
import os
import random  # for generating random point
import numpy as np  # for numerical values manipulation (calculation etc.)
import pandas as pd  # for table/spreadsheets manipulation
os.environ['USE_PYGEOS'] = '0'
import geopandas as gpd  # for geospatial data / attribute table & geometry manipulation 
from shapely import wkt  # for geometry data manipulation
import matplotlib.pyplot as plt  # the most basic and important for making plots/figures in Python 
import seaborn as sns  # convenient tools for making statistical plots

import pingouin as pg  # for running hypothesis testing (T-test, ANOVA)
## https://pingouin-stats.org/build/html/index.html  # go to heir documentation website to check the syntax and roadmap


#from shapely.geometry import Point  # for manipulating point data
#from scipy import stats  # for calculating statistical index
#from scipy import special  # 
#from tqdm import tqdm  # for the progress bar
#import mapclassify as mc  # for generating categorisation for numerical data

# %%
os.listdir('../resources/')
# Out:
# ['hdb_data_2023.csv.xz',
#  'GE5230 Reflection Sheet.docx',
#  'master-plan-2019-planningarea.zip',
#  'BEO_1.md',
#  'hdb_data_2013.csv.xz',
#  '.ipynb_checkpoints',
#  'master-plan-2019-subzone_landuse_area.zip']

# %% [markdown]
# ## load subzone file
#
# load subzone shapefile

# %%
subz = gpd.read_file('../resources/master-plan-2019-subzone_landuse_area.zip')
subz.head()  # get the first 5 rows
# Out:
#     Name                                         descriptio timestamp begin  \
# 0  kml_1  <center><table><tr><th colspan='2' align='cent...      None  None
# 1  kml_2  <center><table><tr><th colspan='2' align='cent...      None  None
# 2  kml_3  <center><table><tr><th colspan='2' align='cent...      None  None
# 3  kml_4  <center><table><tr><th colspan='2' align='cent...      None  None
# 4  kml_5  <center><table><tr><th colspan='2' align='cent...      None  None
#
#     end altitudeMo  tessellate  extrude  visibility drawOrder  ...  \
# 0  None       None          -1        0          -1      None  ...
# 1  None       None          -1        0          -1      None  ...
# 2  None       None          -1        0          -1      None  ...
# 3  None       None          -1        0          -1      None  ...
# 4  None       None          -1        0          -1      None  ...
#
#        FMEL_UPD_D snippet     residentia    commercial      business  \
# 0  20191223152313    None       0.000000      0.000000  0.000000e+00
# 1  20191223152313    None  224478.035778   4323.531384  0.000000e+00
# 2  20191223152313    None  137254.685503  85126.939087  0.000000e+00
# 3  20191223152313    None       0.000000      0.000000  3.329913e+07
# 4  20191223152313    None   13758.277091  12574.427465  0.000000e+00
#
#          outdoor    community_    transporta         other  \
# 0  793768.933514      0.000000  8.019637e+04  9.700715e+05
# 1   22815.913511  18844.910472  7.497035e+04  4.713063e+04
# 2   85012.915334   3113.920177  1.297321e+05  6.634843e+04
# 3   52906.542628   9979.141886  1.710677e+06  1.565466e+06
# 4  219189.323708  24648.825853  5.311558e+04  6.544677e+04
#
#                                             geometry
# 0  POLYGON Z ((33222.981 29588.127 0.000, 33222.5...
# 1  POLYGON Z ((28481.446 30886.220 0.000, 28483.4...
# 2  POLYGON Z ((28087.344 30540.999 0.000, 28087.5...
# 3  MULTIPOLYGON Z (((14557.697 30447.212 0.000, 1...
# 4  POLYGON Z ((29542.526 31041.199 0.000, 29553.7...
#
# [5 rows x 30 columns]

# %%
subz.tail(2)  # get the last 2 rows
# Out:
#         Name                                         descriptio timestamp  \
# 330  kml_331  <center><table><tr><th colspan='2' align='cent...      None
# 331  kml_332  <center><table><tr><th colspan='2' align='cent...      None
#
#     begin   end altitudeMo  tessellate  extrude  visibility drawOrder  ...  \
# 330  None  None       None          -1        0          -1      None  ...
# 331  None  None       None          -1        0          -1      None  ...
#
#          FMEL_UPD_D snippet     residentia    commercial      business  \
# 330  20191223152313    None  752228.171195  37253.532097  1.025488e+05
# 331  20191223152313    None       0.000000      0.000000  1.990602e+07
#
#            outdoor     community_    transporta         other  \
# 330  392445.429134  277777.974909  3.612614e+05  4.062924e+04
# 331   90136.769097   98929.908503  1.581408e+06  6.033533e+06
#
#                                               geometry
# 330  POLYGON Z ((29469.703 36372.102 0.000, 29466.1...
# 331  MULTIPOLYGON Z (((4929.537 32139.355 0.000, 45...
#
# [2 rows x 30 columns]

# %%
subz.plot()  # show the spatial data
# Out:
# <Axes: >

# %%
subz.crs  # this is the EPSG:3414 crs
# Out:
# <Projected CRS: PROJCS["SVY21",GEOGCS["GCS_SVY21[WGS84]",DATUM["WG ...>
# Name: SVY21
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Transverse Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
subz.columns  # show columns, seems like it has too many columns/info
# Out:
# Index(['Name', 'descriptio', 'timestamp', 'begin', 'end', 'altitudeMo',
#        'tessellate', 'extrude', 'visibility', 'drawOrder', 'icon',
#        'SUBZONE_NO', 'SUBZONE_N', 'SUBZONE_C', 'CA_IND', 'PLN_AREA_N',
#        'PLN_AREA_C', 'REGION_N', 'REGION_C', 'INC_CRC', 'FMEL_UPD_D',
#        'snippet', 'residentia', 'commercial', 'business', 'outdoor',
#        'community_', 'transporta', 'other', 'geometry'],
#       dtype='object')

# %%
## remove some non-needed columns, and keep only some important one
keep_cols = [
    'SUBZONE_N', 'SUBZONE_C', 
    'PLN_AREA_N', 'PLN_AREA_C', 
    'REGION_N', 'REGION_C', 
    'geometry']

subz = subz[keep_cols].copy()  # overriding the object by assigning the same name, this can be risky but here is ok
subz.head()
# Out:
#                  SUBZONE_N SUBZONE_C       PLN_AREA_N PLN_AREA_C  \
# 0              MARINA EAST    MESZ01      MARINA EAST         ME
# 1         INSTITUTION HILL    RVSZ05     RIVER VALLEY         RV
# 2           ROBERTSON QUAY    SRSZ01  SINGAPORE RIVER         SR
# 3  JURONG ISLAND AND BUKOM    WISZ01  WESTERN ISLANDS         WI
# 4             FORT CANNING    MUSZ02           MUSEUM         MU
#
#          REGION_N REGION_C                                           geometry
# 0  CENTRAL REGION       CR  POLYGON Z ((33222.981 29588.127 0.000, 33222.5...
# 1  CENTRAL REGION       CR  POLYGON Z ((28481.446 30886.220 0.000, 28483.4...
# 2  CENTRAL REGION       CR  POLYGON Z ((28087.344 30540.999 0.000, 28087.5...
# 3     WEST REGION       WR  MULTIPOLYGON Z (((14557.697 30447.212 0.000, 1...
# 4  CENTRAL REGION       CR  POLYGON Z ((29542.526 31041.199 0.000, 29553.7...

# %% [markdown]
# ## load HDB data

# %%
hdb = pd.read_csv('../resources/hdb_data_2023.csv.xz', index_col=0)  # first (0) column contain 'index' of the rows
hdb.head()  # show the firs 5 rows (by default, is 5 rows)
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2023-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     01 TO 03
# 1  2023-01  ANG MO KIO    2 ROOM   323   ANG MO KIO AVE 3     04 TO 06
# 2  2023-01  ANG MO KIO    2 ROOM   314   ANG MO KIO AVE 3     04 TO 06
# 3  2023-01  ANG MO KIO    2 ROOM   314   ANG MO KIO AVE 3     07 TO 09
# 4  2023-01  ANG MO KIO    2 ROOM   170   ANG MO KIO AVE 4     01 TO 03
#
#    floor_area_sqm flat_model  lease_commence_date  resale_price  resale_year  \
# 0            44.0   Improved                 1979      267000.0         2023
# 1            49.0   Improved                 1977      300000.0         2023
# 2            44.0   Improved                 1978      280000.0         2023
# 3            44.0   Improved                 1978      282000.0         2023
# 4            45.0   Improved                 1986      289800.0         2023
#
#    resale_month  resale_age                ADDRESS       LAT         LNG  \
# 0             1          44  406 ANG MO KIO AVE 10  1.362005  103.853880
# 1             1          46   323 ANG MO KIO AVE 3  1.367908  103.847714
# 2             1          45   314 ANG MO KIO AVE 3  1.366227  103.850086
# 3             1          45   314 ANG MO KIO AVE 3  1.366227  103.850086
# 4             1          37   170 ANG MO KIO AVE 4  1.374001  103.836432
#
#               X             Y  POSTAL  \
# 0  30288.234663  38229.067463  560406
# 1  29602.047153  38881.891694  560323
# 2  29865.998046  38695.970271  560314
# 3  29865.998046  38695.970271  560314
# 4  28346.433332  39555.534275  560170
#
#                                     geometry
# 0  POINT (30288.2346631354 38229.0674628187)
# 1  POINT (29602.0471531954 38881.8916942235)
# 2  POINT (29865.9980458226 38695.9702712912)
# 3  POINT (29865.9980458226 38695.9702712912)
# 4  POINT (28346.4333322113 39555.5342750959)

# %%
hdb.tail(10)  # show the last 10 rows
# Out:
#          month    town         flat_type block     street_name storey_range  \
# 25750  2023-12  YISHUN            5 ROOM  512C    YISHUN ST 51     10 TO 12
# 25751  2023-12  YISHUN            5 ROOM   816    YISHUN ST 81     10 TO 12
# 25752  2023-12  YISHUN         EXECUTIVE   328  YISHUN RING RD     07 TO 09
# 25753  2023-12  YISHUN         EXECUTIVE   326  YISHUN RING RD     07 TO 09
# 25754  2023-12  YISHUN         EXECUTIVE   606    YISHUN ST 61     07 TO 09
# 25755  2023-12  YISHUN         EXECUTIVE   643    YISHUN ST 61     10 TO 12
# 25756  2023-12  YISHUN         EXECUTIVE   643    YISHUN ST 61     10 TO 12
# 25757  2023-12  YISHUN         EXECUTIVE   826    YISHUN ST 81     01 TO 03
# 25758  2023-12  YISHUN         EXECUTIVE   834    YISHUN ST 81     01 TO 03
# 25759  2023-12  YISHUN  MULTI-GENERATION   666    YISHUN AVE 4     01 TO 03
#
#        floor_area_sqm        flat_model  lease_commence_date  resale_price  \
# 25750           113.0          Improved                 2017      750000.0
# 25751           122.0          Improved                 1988      660000.0
# 25752           142.0         Apartment                 1988      798000.0
# 25753           146.0        Maisonette                 1988      770000.0
# 25754           142.0         Apartment                 1987      788888.0
# 25755           146.0        Maisonette                 1987      838000.0
# 25756           142.0         Apartment                 1987      755000.0
# 25757           142.0         Apartment                 1988      780000.0
# 25758           142.0         Apartment                 1988      785000.0
# 25759           179.0  Multi Generation                 1987      975000.0
#
#        resale_year  resale_month  resale_age             ADDRESS       LAT  \
# 25750         2023            12           6   512C YISHUN ST 51  1.414958
# 25751         2023            12          35    816 YISHUN ST 81  1.411771
# 25752         2023            12          35  328 YISHUN RING RD  1.429780
# 25753         2023            12          35  326 YISHUN RING RD  1.429551
# 25754         2023            12          36    606 YISHUN ST 61  1.421334
# 25755         2023            12          36    643 YISHUN ST 61  1.421335
# 25756         2023            12          36    643 YISHUN ST 61  1.421335
# 25757         2023            12          35    826 YISHUN ST 81  1.414174
# 25758         2023            12          35    834 YISHUN ST 81  1.415088
# 25759         2023            12          36    666 YISHUN AVE 4  1.418998
#
#               LNG             X             Y  POSTAL  \
# 25750  103.842655  29039.008991  44084.358214  763512
# 25751  103.833368  28005.529905  43731.974231  760816
# 25752  103.843057  29083.732600  45723.276519  760328
# 25753  103.842440  29015.047402  45698.010440  760326
# 25754  103.836318  28333.820088  44789.428103  760606
# 25755  103.837437  28458.318995  44789.537249  760643
# 25756  103.837437  28458.318995  44789.537249  760643
# 25757  103.832454  27903.805992  43997.703489  760826
# 25758  103.834000  28075.777355  44098.765290  760834
# 25759  103.840568  28806.756365  44531.159086  760666
#
#                                         geometry
# 25750  POINT (29039.0089909183 44084.3582140561)
# 25751  POINT (28005.5299047483 43731.9742311724)
# 25752  POINT (29083.7326004431 45723.2765188329)
# 25753  POINT (29015.0474021444 45698.0104404967)
# 25754  POINT (28333.8200883046 44789.4281029589)
# 25755  POINT (28458.3189945575 44789.5372493081)
# 25756  POINT (28458.3189945575 44789.5372493081)
# 25757  POINT (27903.8059915034 43997.7034889162)
# 25758  POINT (28075.7773547592 44098.7652900182)
# 25759  POINT (28806.7563653113 44531.1590859666)

# %%
hdb.columns  # to check what columns is included in the csv/dataframe
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date', 'resale_price',
#        'resale_year', 'resale_month', 'resale_age', 'ADDRESS', 'LAT', 'LNG',
#        'X', 'Y', 'POSTAL', 'geometry'],
#       dtype='object')

# %%
hdb['geometry'].apply(wkt.loads)  ## this is what this .apply() do
# Out:
# 0        POINT (30288.2346631354 38229.0674628187)
# 1        POINT (29602.0471531954 38881.8916942235)
# 2        POINT (29865.9980458226 38695.9702712912)
# 3        POINT (29865.9980458226 38695.9702712912)
# 4        POINT (28346.4333322113 39555.5342750959)
#                            ...
# 25755    POINT (28458.3189945575 44789.5372493081)
# 25756    POINT (28458.3189945575 44789.5372493081)
# 25757    POINT (27903.8059915034 43997.7034889162)
# 25758    POINT (28075.7773547592 44098.7652900182)
# 25759    POINT (28806.7563653113 44531.1590859666)
# Name: geometry, Length: 25760, dtype: object

# %%
g_hdb = gpd.GeoDataFrame(data=hdb,
                         geometry=hdb['geometry'].apply(wkt.loads), 
                         crs=subz.crs)  # use the same crs as the subzone, make sure they are same before setting it
g_hdb.plot()
# Out:
# <Axes: >

# %%
## X.sjoin(Y) is the spatial join function, joining the Y to X
## in this case, is to join the polygon info to the point
g_hdb.sjoin(subz)  # testing how it looks, without keeping the test result as a new object
# Out:
#          month        town         flat_type block        street_name  \
# 0      2023-01  ANG MO KIO            2 ROOM   406  ANG MO KIO AVE 10
# 1      2023-01  ANG MO KIO            2 ROOM   323   ANG MO KIO AVE 3
# 2      2023-01  ANG MO KIO            2 ROOM   314   ANG MO KIO AVE 3
# 3      2023-01  ANG MO KIO            2 ROOM   314   ANG MO KIO AVE 3
# 4      2023-01  ANG MO KIO            2 ROOM   170   ANG MO KIO AVE 4
# ...        ...         ...               ...   ...                ...
# 25755  2023-12      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 25756  2023-12      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 25757  2023-12      YISHUN         EXECUTIVE   826       YISHUN ST 81
# 25758  2023-12      YISHUN         EXECUTIVE   834       YISHUN ST 81
# 25759  2023-12      YISHUN  MULTI-GENERATION   666       YISHUN AVE 4
#
#       storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# 0         01 TO 03            44.0          Improved                 1979
# 1         04 TO 06            49.0          Improved                 1977
# 2         04 TO 06            44.0          Improved                 1978
# 3         07 TO 09            44.0          Improved                 1978
# 4         01 TO 03            45.0          Improved                 1986
# ...            ...             ...               ...                  ...
# 25755     10 TO 12           146.0        Maisonette                 1987
# 25756     10 TO 12           142.0         Apartment                 1987
# 25757     01 TO 03           142.0         Apartment                 1988
# 25758     01 TO 03           142.0         Apartment                 1988
# 25759     01 TO 03           179.0  Multi Generation                 1987
#
#        resale_price  ...             Y  POSTAL                     geometry  \
# 0          267000.0  ...  38229.067463  560406  POINT (30288.235 38229.067)
# 1          300000.0  ...  38881.891694  560323  POINT (29602.047 38881.892)
# 2          280000.0  ...  38695.970271  560314  POINT (29865.998 38695.970)
# 3          282000.0  ...  38695.970271  560314  POINT (29865.998 38695.970)
# 4          289800.0  ...  39555.534275  560170  POINT (28346.433 39555.534)
# ...             ...  ...           ...     ...                          ...
# 25755      838000.0  ...  44789.537249  760643  POINT (28458.319 44789.537)
# 25756      755000.0  ...  44789.537249  760643  POINT (28458.319 44789.537)
# 25757      780000.0  ...  43997.703489  760826  POINT (27903.806 43997.703)
# 25758      785000.0  ...  44098.765290  760834  POINT (28075.777 44098.765)
# 25759      975000.0  ...  44531.159086  760666  POINT (28806.756 44531.159)
#
#       index_right     SUBZONE_N  SUBZONE_C  PLN_AREA_N  PLN_AREA_C  \
# 0             162    CHONG BOON     AMSZ03  ANG MO KIO          AM
# 1             329    TOWNSVILLE     AMSZ04  ANG MO KIO          AM
# 2             329    TOWNSVILLE     AMSZ04  ANG MO KIO          AM
# 3             329    TOWNSVILLE     AMSZ04  ANG MO KIO          AM
# 4             171   KEBUN BAHRU     AMSZ06  ANG MO KIO          AM
# ...           ...           ...        ...         ...         ...
# 25755         221  YISHUN SOUTH     YSSZ04      YISHUN          YS
# 25756         221  YISHUN SOUTH     YSSZ04      YISHUN          YS
# 25757         221  YISHUN SOUTH     YSSZ04      YISHUN          YS
# 25758         221  YISHUN SOUTH     YSSZ04      YISHUN          YS
# 25759         221  YISHUN SOUTH     YSSZ04      YISHUN          YS
#
#                 REGION_N REGION_C
# 0      NORTH-EAST REGION      NER
# 1      NORTH-EAST REGION      NER
# 2      NORTH-EAST REGION      NER
# 3      NORTH-EAST REGION      NER
# 4      NORTH-EAST REGION      NER
# ...                  ...      ...
# 25755       NORTH REGION       NR
# 25756       NORTH REGION       NR
# 25757       NORTH REGION       NR
# 25758       NORTH REGION       NR
# 25759       NORTH REGION       NR
#
# [25760 rows x 27 columns]

# %%
g_hdb2 = g_hdb.sjoin(subz)  # save the  spatial join result as a new geopandas object
# assign it to a new name, which is safer (not overriding)
g_hdb2.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2023-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     01 TO 03
# 1  2023-01  ANG MO KIO    2 ROOM   323   ANG MO KIO AVE 3     04 TO 06
# 2  2023-01  ANG MO KIO    2 ROOM   314   ANG MO KIO AVE 3     04 TO 06
# 3  2023-01  ANG MO KIO    2 ROOM   314   ANG MO KIO AVE 3     07 TO 09
# 4  2023-01  ANG MO KIO    2 ROOM   170   ANG MO KIO AVE 4     01 TO 03
#
#    floor_area_sqm flat_model  lease_commence_date  resale_price  ...  \
# 0            44.0   Improved                 1979      267000.0  ...
# 1            49.0   Improved                 1977      300000.0  ...
# 2            44.0   Improved                 1978      280000.0  ...
# 3            44.0   Improved                 1978      282000.0  ...
# 4            45.0   Improved                 1986      289800.0  ...
#
#               Y  POSTAL                     geometry index_right    SUBZONE_N  \
# 0  38229.067463  560406  POINT (30288.235 38229.067)         162   CHONG BOON
# 1  38881.891694  560323  POINT (29602.047 38881.892)         329   TOWNSVILLE
# 2  38695.970271  560314  POINT (29865.998 38695.970)         329   TOWNSVILLE
# 3  38695.970271  560314  POINT (29865.998 38695.970)         329   TOWNSVILLE
# 4  39555.534275  560170  POINT (28346.433 39555.534)         171  KEBUN BAHRU
#
#    SUBZONE_C  PLN_AREA_N  PLN_AREA_C           REGION_N REGION_C
# 0     AMSZ03  ANG MO KIO          AM  NORTH-EAST REGION      NER
# 1     AMSZ04  ANG MO KIO          AM  NORTH-EAST REGION      NER
# 2     AMSZ04  ANG MO KIO          AM  NORTH-EAST REGION      NER
# 3     AMSZ04  ANG MO KIO          AM  NORTH-EAST REGION      NER
# 4     AMSZ06  ANG MO KIO          AM  NORTH-EAST REGION      NER
#
# [5 rows x 27 columns]

# %% [markdown]
# ## try individual transaction analysis
#
# check the resale prices between regions

# %%
sns.histplot(g_hdb2['resale_price'])
# Out:
# <Axes: xlabel='resale_price', ylabel='Count'>

# %%
sns.boxplot(x='REGION_C', y='resale_price', data=g_hdb2)
# Out:
# <Axes: xlabel='REGION_C', ylabel='resale_price'>

# %%
sns.violinplot(x='REGION_C', y='resale_price', data=g_hdb2)
# Out:
# <Axes: xlabel='REGION_C', ylabel='resale_price'>

# %%
sns.violinplot(x='floor_area_sqm', y='resale_price', data=g_hdb2)
# Out:
# <Axes: xlabel='floor_area_sqm', ylabel='resale_price'>

# %%
sns.boxplot(x='flat_type', y='resale_price', data=g_hdb2)
# Out:
# <Axes: xlabel='flat_type', ylabel='resale_price'>

# %%
sns.boxplot(x='flat_type', y='resale_price', hue='REGION_C', data=g_hdb2)
# Out:
# <Axes: xlabel='flat_type', ylabel='resale_price'>

# %% [markdown]
# let's rearange things so that it is more intuitive

# %%
sns.boxplot(x='flat_type', y='resale_price', hue='REGION_C', data=g_hdb2,
            order=['2 ROOM', '3 ROOM', '4 ROOM', '5 ROOM'], 
            hue_order=['NR', 'WR', 'ER', 'NER', 'CR'],
           )
# Out:
# <Axes: xlabel='flat_type', ylabel='resale_price'>

# %%
sns.color_palette('muted')
# Out:
# [(0.2823529411764706, 0.47058823529411764, 0.8156862745098039),
#  (0.9333333333333333, 0.5215686274509804, 0.2901960784313726),
#  (0.41568627450980394, 0.8, 0.39215686274509803),
#  (0.8392156862745098, 0.37254901960784315, 0.37254901960784315),
#  (0.5843137254901961, 0.4235294117647059, 0.7058823529411765),
#  (0.5490196078431373, 0.3803921568627451, 0.23529411764705882),
#  (0.8627450980392157, 0.49411764705882355, 0.7529411764705882),
#  (0.4745098039215686, 0.4745098039215686, 0.4745098039215686),
#  (0.8352941176470589, 0.7333333333333333, 0.403921568627451),
#  (0.5098039215686274, 0.7764705882352941, 0.8862745098039215)]

# %%
sns.boxplot(x='flat_type', y='resale_price', hue='REGION_C', data=g_hdb2,
            order=['2 ROOM', '3 ROOM', '4 ROOM', '5 ROOM'], 
            hue_order=['NR', 'WR', 'ER', 'NER', 'CR'],
            palette=sns.color_palette('bright')[:5]
           )
# Out:
# <Axes: xlabel='flat_type', ylabel='resale_price'>

# %% [markdown]
# # an interesting point here:
# - CR is lower than other regions for 2 room, about the same for 3 room, and higher than other zones for 4 and 5 rooms
# - for 2/3 rooms, the outliers are visibly higher
#
# **is it because of the numbers are less in CR?, let's check**

# %%
g_hdb2.groupby('REGION_C')[['resale_price']].count()
# Out:
#           resale_price
# REGION_C
# CR                4487
# ER                3568
# NER               6916
# NR                4889
# WR                5900

# %%
g_hdb2.groupby(['flat_type', 'REGION_C'])[['resale_price']].count()
# Out:
#                            resale_price
# flat_type        REGION_C
# 1 ROOM           CR                   6
# 2 ROOM           CR                 128
#                  ER                  34
#                  NER                201
#                  NR                 197
#                  WR                 129
# 3 ROOM           CR                1817
#                  ER                 981
#                  NER               1386
#                  NR                 872
#                  WR                1300
# 4 ROOM           CR                1744
#                  ER                1394
#                  NER               3294
#                  NR                2355
#                  WR                2571
# 5 ROOM           CR                 676
#                  ER                 840
#                  NER               1717
#                  NR                1161
#                  WR                1451
# EXECUTIVE        CR                 116
#                  ER                 319
#                  NER                318
#                  NR                 301
#                  WR                 449
# MULTI-GENERATION NR                   3

# %% [markdown]
# in terms of # transaction, CR doesn't seem to be different from others
# note that the word 'seem'<--means visually speaking

# %% [markdown]
# ### remark 1
# so, different flat type may have different price pattern between regions
#
# traditionally we may want to use 2-ways anova, here let's use what we cover in the class: one-way anova
#
# run one-way ANOVA separately for different flat type, between REGION

# %%
g_hdb2['flat_type']=='1 ROOM', len(g_hdb2)
# Out:
# (0        False
#  1        False
#  2        False
#  3        False
#  4        False
#           ...
#  25755    False
#  25756    False
#  25757    False
#  25758    False
#  25759    False
#  Name: flat_type, Length: 25760, dtype: bool,
#  25760)

# %%
g_hdb2[g_hdb2['flat_type']=='1 ROOM']
# Out:
#          month         town flat_type block         street_name storey_range  \
# 4750   2023-03  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES     01 TO 03
# 7020   2023-04  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES     04 TO 06
# 9229   2023-05  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES     01 TO 03
# 19805  2023-10  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES     01 TO 03
# 19806  2023-10  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES     04 TO 06
# 21994  2023-11  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES     10 TO 12
#
#        floor_area_sqm flat_model  lease_commence_date  resale_price  ...  \
# 4750             31.0   Improved                 1975      237000.0  ...
# 7020             31.0   Improved                 1975      240000.0  ...
# 9229             31.0   Improved                 1975      251000.0  ...
# 19805            31.0   Improved                 1975      243000.0  ...
# 19806            31.0   Improved                 1975      229000.0  ...
# 21994            31.0   Improved                 1975      258000.0  ...
#
#                  Y  POSTAL                     geometry index_right  \
# 4750   28980.23008  090007  POINT (26449.194 28980.230)          17
# 7020   28980.23008  090007  POINT (26449.194 28980.230)          17
# 9229   28980.23008  090007  POINT (26449.194 28980.230)          17
# 19805  28980.23008  090007  POINT (26449.194 28980.230)          17
# 19806  28980.23008  090007  POINT (26449.194 28980.230)          17
# 21994  28980.23008  090007  POINT (26449.194 28980.230)          17
#
#                SUBZONE_N  SUBZONE_C   PLN_AREA_N  PLN_AREA_C        REGION_N  \
# 4750   TELOK BLANGAH WAY     BMSZ14  BUKIT MERAH          BM  CENTRAL REGION
# 7020   TELOK BLANGAH WAY     BMSZ14  BUKIT MERAH          BM  CENTRAL REGION
# 9229   TELOK BLANGAH WAY     BMSZ14  BUKIT MERAH          BM  CENTRAL REGION
# 19805  TELOK BLANGAH WAY     BMSZ14  BUKIT MERAH          BM  CENTRAL REGION
# 19806  TELOK BLANGAH WAY     BMSZ14  BUKIT MERAH          BM  CENTRAL REGION
# 21994  TELOK BLANGAH WAY     BMSZ14  BUKIT MERAH          BM  CENTRAL REGION
#
#       REGION_C
# 4750        CR
# 7020        CR
# 9229        CR
# 19805       CR
# 19806       CR
# 21994       CR
#
# [6 rows x 27 columns]

# %%
ftypes = ['2 ROOM', '3 ROOM', '4 ROOM', '5 ROOM']

## declare the empty list for storing results
a_res_all = []  # for storing anova result
ph_res_all = []  # for storing post-hoc result
for ft in ftypes:
    tmp = g_hdb2[g_hdb2['flat_type']==ft]
    #print(ft, len(tmp))
    # run anova
    a_res = pg.anova(data=tmp, dv='resale_price', between='REGION_C',)
    a_res['flat_type'] = ft
    #print(a_res)
    a_res_all.append(a_res) # store anova result
    # run post-hoc 
    ph_res = pg.pairwise_tukey(data=tmp, dv='resale_price', between='REGION_C').round(3)
    #ph_res['p-tukey'] = ph_res['p-tukey'].round(4)
    ph_res['mean(A)'] = ph_res['mean(A)'].round(1)
    ph_res['mean(B)'] = ph_res['mean(B)'].round(1)
    ph_res['diff'] = ph_res['diff'].round(1)
    ph_res['flat_type'] = ft
    #print(ph_res)
    ph_res_all.append(ph_res)  # store post-hoc result
    
a_res_all = pd.concat(a_res_all)  # combine the dataframes in the list into one dataframe
#ph_res_all = pd.concat(ph_res_all)
a_res_all#, ph_res_all
# Out:
#      Source  ddof1  ddof2            F         p-unc       np2 flat_type
# 0  REGION_C      4    684    13.981083  5.702313e-11  0.075581    2 ROOM
# 0  REGION_C      4   6351    58.785339  8.328396e-49  0.035702    3 ROOM
# 0  REGION_C      4  11353  1644.679298  0.000000e+00  0.366876    4 ROOM
# 0  REGION_C      4   5840   865.388524  0.000000e+00  0.372148    5 ROOM

# %%
for ph_res in ph_res_all:
    tmp = ph_res[ph_res['p-tukey']<=.05]  # filter to get significant row only
    print(tmp)
# Out:
#      A    B   mean(A)   mean(B)     diff        se      T  p-tukey  hedges  \
# 0   CR   ER  300024.4  331823.5 -31799.1  7635.973 -4.164    0.000  -0.477
# 1   CR  NER  300024.4  332277.5 -32253.1  4475.548 -7.207    0.000  -0.654
# 2   CR   NR  300024.4  323819.1 -23794.7  4493.191 -5.296    0.000  -0.490
# 3   CR   WR  300024.4  319457.4 -19432.9  4937.624 -3.936    0.001  -0.344
# 8  NER   WR  332277.5  319457.4  12820.1  4464.938  2.871    0.034   0.444
#
#   flat_type
# 0    2 ROOM
# 1    2 ROOM
# 2    2 ROOM
# 3    2 ROOM
# 8    2 ROOM
#      A    B   mean(A)   mean(B)     diff        se       T  p-tukey  hedges  \
# 0   CR   ER  433591.6  401849.1  31742.5  3442.264   9.221      0.0   0.286
# 1   CR  NER  433591.6  419594.1  13997.5  3098.501   4.518      0.0   0.131
# 2   CR   NR  433591.6  393648.0  39943.6  3579.249  11.160      0.0   0.359
# 3   CR   WR  433591.6  393328.1  40263.6  3156.105  12.757      0.0   0.363
# 4   ER  NER  401849.1  419594.1 -17745.0  3625.060  -4.895      0.0  -0.307
# 7  NER   NR  419594.1  393648.0  25946.1  3755.384   6.909      0.0   0.476
# 8  NER   WR  419594.1  393328.1  26266.0  3354.532   7.830      0.0   0.399
#
#   flat_type
# 0    3 ROOM
# 1    3 ROOM
# 2    3 ROOM
# 3    3 ROOM
# 4    3 ROOM
# 7    3 ROOM
# 8    3 ROOM
#      A    B   mean(A)   mean(B)      diff        se       T  p-tukey  hedges  \
# 0   CR   ER  763596.3  573620.1  189976.2  3835.342  49.533      0.0   1.278
# 1   CR  NER  763596.3  582567.0  181029.3  3161.377  57.263      0.0   1.390
# 2   CR   NR  763596.3  508916.7  254679.6  3372.504  75.516      0.0   2.018
# 3   CR   WR  763596.3  538650.5  224945.8  3311.680  67.925      0.0   1.644
# 5   ER   NR  573620.1  508916.7   64703.4  3607.556  17.936      0.0   0.878
# 6   ER   WR  573620.1  538650.5   34969.6  3550.761   9.848      0.0   0.368
# 7  NER   NR  582567.0  508916.7   73650.3  2880.785  25.566      0.0   0.915
# 8  NER   WR  582567.0  538650.5   43916.5  2809.334  15.632      0.0   0.466
# 9   NR   WR  508916.7  538650.5  -29733.8  3044.970  -9.765      0.0  -0.370
#
#   flat_type
# 0    4 ROOM
# 1    4 ROOM
# 2    4 ROOM
# 3    4 ROOM
# 5    4 ROOM
# 6    4 ROOM
# 7    4 ROOM
# 8    4 ROOM
# 9    4 ROOM
#      A    B   mean(A)   mean(B)      diff        se       T  p-tukey  hedges  \
# 0   CR   ER  912139.3  690956.7  221182.5  5788.705  38.209    0.000   1.609
# 1   CR  NER  912139.3  676094.6  236044.6  5086.952  46.402    0.000   1.768
# 2   CR   NR  912139.3  612214.4  299924.8  5420.133  55.335    0.000   2.487
# 3   CR   WR  912139.3  645582.3  266557.0  5217.008  51.094    0.000   1.907
# 4   ER  NER  690956.7  676094.6   14862.1  4717.212   3.151    0.014   0.144
# 5   ER   NR  690956.7  612214.4   78742.3  5074.726  15.517    0.000   1.050
# 6   ER   WR  690956.7  645582.3   45374.5  4857.178   9.342    0.000   0.425
# 7  NER   NR  676094.6  612214.4   63880.2  4256.856  15.006    0.000   0.682
# 8  NER   WR  676094.6  645582.3   30512.4  3995.016   7.638    0.000   0.271
# 9   NR   WR  612214.4  645582.3  -33367.8  4411.452  -7.564    0.000  -0.347
#
#   flat_type
# 0    5 ROOM
# 1    5 ROOM
# 2    5 ROOM
# 3    5 ROOM
# 4    5 ROOM
# 5    5 ROOM
# 6    5 ROOM
# 7    5 ROOM
# 8    5 ROOM
# 9    5 ROOM

# %% [markdown]
# ## summary
#
# - for 2 room, CR is significantly lower than all others; NER > WR
# - for 3 room, CR is significantly higher than all others (this is not visible); NER > (ER, NR, WR)
# - for 4 and 5 rooms:
#     - CR > all
#     - ER > most of them
#     - NER > NR & WR
#     - NR < WR
# - ER and NER, some times one is significantly higher than another, which does not always stand for other flat type
#     - this means that, for different flat types, the relationship (> or <) may change between regions

# %% [markdown]
# ## try to see how the different flat type in each region

# %%
regs = ['CR', 'ER', 'NR', 'NER', 'WR']

a_res_all2 = []
for reg in regs:
    tmp = g_hdb2[g_hdb2['REGION_C']==reg]
    #print(tmp.head())
    a_res = pg.anova(data=tmp, dv='resale_price', between='flat_type',)
    a_res['REGION_C'] = reg
    a_res_all2.append(a_res)
    print(a_res)
    break

# note the ddof1: the flat type contains 1 room, executive, and multi-gen, which we don't want
# Out:
#       Source  ddof1  ddof2            F  p-unc       np2 REGION_C
# 0  flat_type      5   4481  1487.958521    0.0  0.624102       CR

# %%
keep_ft = ['2 ROOM', '3 ROOM', '4 ROOM', '5 ROOM']
g_hdb3 = g_hdb2[[ft in keep_ft for ft in g_hdb2['flat_type']]].copy()
len(g_hdb3)
# Out:
# 24248

# %%
regs = ['CR', 'ER', 'NR', 'NER', 'WR']

a_res_all2 = []
ph_res_all2 = []
for reg in regs:
    tmp = g_hdb3[g_hdb3['REGION_C']==reg]
    #print(tmp.head())
    a_res = pg.anova(data=tmp, dv='resale_price', between='flat_type',)
    a_res['REGION_C'] = reg
    a_res_all2.append(a_res)
    #print(a_res)  # check the ddof1 and ddof2
    ph_res = pg.pairwise_tukey(data=tmp, dv='resale_price', between='flat_type').round(3)
    #ph_res['p-tukey'] = ph_res['p-tukey'].round(4)
    ph_res['mean(A)'] = ph_res['mean(A)'].round(1)
    ph_res['mean(B)'] = ph_res['mean(B)'].round(1)
    ph_res['diff'] = ph_res['diff'].round(1)
    ph_res['flat_type'] = reg
    #print(ph_res)
    ph_res_all2.append(ph_res)
    #break

a_res_all2 = pd.concat(a_res_all2)  # combine the dataframes in the list into one dataframe
a_res_all2
# Out:
#       Source  ddof1  ddof2            F  p-unc       np2 REGION_C
# 0  flat_type      3   4361  2207.724091    0.0  0.602974       CR
# 0  flat_type      3   3245  2015.361828    0.0  0.650740       ER
# 0  flat_type      3   4581  3166.579463    0.0  0.674662       NR
# 0  flat_type      3   6594  2543.364540    0.0  0.536420      NER
# 0  flat_type      3   5447  1798.161356    0.0  0.497578       WR

# %%
for ph in ph_res_all2:
    ph2 = ph[ph['p-tukey']<=.05]
    print(ph)
# Out:
#         A       B   mean(A)   mean(B)      diff         se       T  p-tukey  \
# 0  2 ROOM  3 ROOM  300024.4  433591.6 -133567.2  14600.533  -9.148      0.0
# 1  2 ROOM  4 ROOM  300024.4  763596.3 -463571.9  14620.629 -31.707      0.0
# 2  2 ROOM  5 ROOM  300024.4  912139.3 -612114.8  15390.086 -39.773      0.0
# 3  3 ROOM  4 ROOM  433591.6  763596.3 -330004.7   5352.130 -61.659      0.0
# 4  3 ROOM  5 ROOM  433591.6  912139.3 -478547.6   7192.861 -66.531      0.0
# 5  4 ROOM  5 ROOM  763596.3  912139.3 -148542.9   7233.566 -20.535      0.0
#
#    hedges flat_type
# 0  -1.039        CR
# 1  -2.637        CR
# 2  -3.638        CR
# 3  -2.092        CR
# 4  -3.267        CR
# 5  -0.821        CR
#         A       B   mean(A)   mean(B)      diff         se       T  p-tukey  \
# 0  2 ROOM  3 ROOM  331823.5  401849.1  -70025.6  14298.016  -4.898      0.0
# 1  2 ROOM  4 ROOM  331823.5  573620.1 -241796.6  14226.890 -16.996      0.0
# 2  2 ROOM  5 ROOM  331823.5  690956.7 -359133.2  14338.157 -25.047      0.0
# 3  3 ROOM  4 ROOM  401849.1  573620.1 -171771.0   3415.723 -50.288      0.0
# 4  3 ROOM  5 ROOM  401849.1  690956.7 -289107.6   3852.987 -75.035      0.0
# 5  4 ROOM  5 ROOM  573620.1  690956.7 -117336.7   3580.035 -32.775      0.0
#
#    hedges flat_type
# 0  -1.272        ER
# 1  -2.612        ER
# 2  -4.123        ER
# 3  -2.146        ER
# 4  -3.979        ER
# 5  -1.280        ER
#         A       B   mean(A)   mean(B)      diff        se       T  p-tukey  \
# 0  2 ROOM  3 ROOM  323819.1  393648.0  -69828.9  4481.585 -15.581      0.0
# 1  2 ROOM  4 ROOM  323819.1  508916.7 -185097.6  4213.528 -43.929      0.0
# 2  2 ROOM  5 ROOM  323819.1  612214.4 -288395.3  4377.587 -65.880      0.0
# 3  3 ROOM  4 ROOM  393648.0  508916.7 -115268.7  2252.060 -51.184      0.0
# 4  3 ROOM  5 ROOM  393648.0  612214.4 -218566.4  2545.825 -85.853      0.0
# 5  4 ROOM  5 ROOM  508916.7  612214.4 -103297.8  2037.263 -50.704      0.0
#
#    hedges flat_type
# 0  -1.636        NR
# 1  -3.248        NR
# 2  -4.865        NR
# 3  -2.067        NR
# 4  -3.859        NR
# 5  -1.708        NR
#         A       B   mean(A)   mean(B)      diff        se       T  p-tukey  \
# 0  2 ROOM  3 ROOM  332277.5  419594.1  -87316.6  6825.412 -12.793      0.0
# 1  2 ROOM  4 ROOM  332277.5  582567.0 -250289.5  6570.279 -38.094      0.0
# 2  2 ROOM  5 ROOM  332277.5  676094.6 -343817.1  6741.572 -51.000      0.0
# 3  3 ROOM  4 ROOM  419594.1  582567.0 -162972.9  2895.340 -56.288      0.0
# 4  3 ROOM  5 ROOM  419594.1  676094.6 -256500.5  3265.458 -78.550      0.0
# 5  4 ROOM  5 ROOM  582567.0  676094.6  -93527.6  2691.754 -34.746      0.0
#
#    hedges flat_type
# 0  -1.557       NER
# 1  -2.771       NER
# 2  -3.305       NER
# 3  -1.934       NER
# 4  -2.831       NER
# 5  -0.946       NER
#         A       B   mean(A)   mean(B)      diff        se       T  p-tukey  \
# 0  2 ROOM  3 ROOM  319457.4  393328.1  -73870.7  8845.880  -8.351      0.0
# 1  2 ROOM  4 ROOM  319457.4  538650.5 -219193.1  8646.244 -25.351      0.0
# 2  2 ROOM  5 ROOM  319457.4  645582.3 -326124.9  8804.232 -37.042      0.0
# 3  3 ROOM  4 ROOM  393328.1  538650.5 -145322.4  3261.222 -44.561      0.0
# 4  3 ROOM  5 ROOM  393328.1  645582.3 -252254.2  3659.581 -68.930      0.0
# 5  4 ROOM  5 ROOM  538650.5  645582.3 -106931.8  3146.500 -33.984      0.0
#
#    hedges flat_type
# 0  -1.059        WR
# 1  -2.336        WR
# 2  -2.923        WR
# 3  -1.639        WR
# 4  -2.580        WR
# 5  -1.033        WR

# %% [markdown]
# all regions indicated that 2 room < 3 room < 4 room < 5 room

# %% [markdown]
# ## test run 2-ways anova

# %%
pg.anova(data=g_hdb3, dv='resale_price', between=['REGION_C', 'flat_type'], detailed=True)
# Out:
#                  Source            SS       DF            MS             F  \
# 0              REGION_C  8.450466e+13      4.0  2.112617e+13   2033.595336
# 1             flat_type  3.162643e+14      3.0  1.054214e+14  10147.820819
# 2  REGION_C * flat_type  3.577816e+13     12.0  2.981513e+12    286.999119
# 3              Residual  2.516945e+14  24228.0  1.038858e+10           NaN
#
#    p-unc       np2
# 0    0.0  0.251353
# 1    0.0  0.556844
# 2    0.0  0.124458
# 3    NaN       NaN

# %% [markdown]
# the two main effects (regions and flat type) are significant, as well as the interaction effect

# %% [markdown]
# ## try aggregated analysis (aggregate by subzone) and mixed anova
#
# mixed means contains both between and within data
# - between: mutually exclusive groups, subjects in one 'group' cannot appear in another 'group'
# - within: every subject must have one value in the all 'groups'
#
# individual transaction data is mutually exclusive, because all transaction happens in only one location, has one flat type, has one and only one value in all columns.... so there is no 'within' group properties in it
#
# to demonstrate mixed anova, we need to aggregate the transaction into some spatial units, then the spatial units can contains multiple transactions that falls in different groups, e.g., different flat types appear in the same subzone. Then, we can calculate the median/mean price for each type in the same subzone.

# %%
g_hdb3.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2023-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     01 TO 03
# 1  2023-01  ANG MO KIO    2 ROOM   323   ANG MO KIO AVE 3     04 TO 06
# 2  2023-01  ANG MO KIO    2 ROOM   314   ANG MO KIO AVE 3     04 TO 06
# 3  2023-01  ANG MO KIO    2 ROOM   314   ANG MO KIO AVE 3     07 TO 09
# 4  2023-01  ANG MO KIO    2 ROOM   170   ANG MO KIO AVE 4     01 TO 03
#
#    floor_area_sqm flat_model  lease_commence_date  resale_price  ...  \
# 0            44.0   Improved                 1979      267000.0  ...
# 1            49.0   Improved                 1977      300000.0  ...
# 2            44.0   Improved                 1978      280000.0  ...
# 3            44.0   Improved                 1978      282000.0  ...
# 4            45.0   Improved                 1986      289800.0  ...
#
#               Y  POSTAL                     geometry index_right    SUBZONE_N  \
# 0  38229.067463  560406  POINT (30288.235 38229.067)         162   CHONG BOON
# 1  38881.891694  560323  POINT (29602.047 38881.892)         329   TOWNSVILLE
# 2  38695.970271  560314  POINT (29865.998 38695.970)         329   TOWNSVILLE
# 3  38695.970271  560314  POINT (29865.998 38695.970)         329   TOWNSVILLE
# 4  39555.534275  560170  POINT (28346.433 39555.534)         171  KEBUN BAHRU
#
#    SUBZONE_C  PLN_AREA_N  PLN_AREA_C           REGION_N REGION_C
# 0     AMSZ03  ANG MO KIO          AM  NORTH-EAST REGION      NER
# 1     AMSZ04  ANG MO KIO          AM  NORTH-EAST REGION      NER
# 2     AMSZ04  ANG MO KIO          AM  NORTH-EAST REGION      NER
# 3     AMSZ04  ANG MO KIO          AM  NORTH-EAST REGION      NER
# 4     AMSZ06  ANG MO KIO          AM  NORTH-EAST REGION      NER
#
# [5 rows x 27 columns]

# %%
g_hdb3.groupby('SUBZONE_N')[['resale_price']].mean()
# Out:
#                  resale_price
# SUBZONE_N
# ADMIRALTY       491582.265060
# ALEXANDRA HILL  598892.294085
# ALJUNIED        579236.190476
# ANAK BUKIT      921494.909091
# ANCHORVALE      574497.724138
# ...                       ...
# YISHUN SOUTH    523087.597674
# YISHUN WEST     415818.701754
# YUHUA EAST      456596.260274
# YUHUA WEST      452366.610526
# YUNNAN          487901.138577
#
# [151 rows x 1 columns]

# %% [raw]
# tmp = (g_hdb3['resale_age']/10).astype(int)*10
# ## 0: 0 -- 9
# ## 10: 10 -- 19 ...
# #tmp
# g_hdb3['resale_age_group'] = tmp

# %% [raw]
# sns.boxplot(x='resale_age_group', y='resale_price', data=g_hdb3)

# %% [raw]
# g_hdb3.groupby('resale_age_group')[['resale_price']].count()

# %% [raw]
# regroup = {
#     0: 0,
#     10: 1,
#     20: 1,
#     30: 2,
#     40: 2,
#     50: 2,
# }

# %%
g_hdb4 = g_hdb3.groupby(['REGION_C', 'SUBZONE_N', 'flat_type'])[['resale_price']].median().reset_index()

g_hdb4  ## long table
# Out:
#     REGION_C       SUBZONE_N flat_type  resale_price
# 0         CR  ALEXANDRA HILL    2 ROOM      290000.0
# 1         CR  ALEXANDRA HILL    3 ROOM      328000.0
# 2         CR  ALEXANDRA HILL    4 ROOM      700000.0
# 3         CR  ALEXANDRA HILL    5 ROOM      836944.0
# 4         CR        ALJUNIED    2 ROOM      297500.0
# ..       ...             ...       ...           ...
# 482       WR      YUHUA WEST    5 ROOM      600000.0
# 483       WR          YUNNAN    2 ROOM      280000.0
# 484       WR          YUNNAN    3 ROOM      365000.0
# 485       WR          YUNNAN    4 ROOM      460000.0
# 486       WR          YUNNAN    5 ROOM      560000.0
#
# [487 rows x 4 columns]

# %%
g_hdb4b = g_hdb4.pivot(index=['REGION_C', 'SUBZONE_N'], columns='flat_type', values='resale_price').reset_index()
## all 'within group' data can be arranged into wide table, like this, 
## where each row represent a subject, and multiple columns containing the same variable (resale price) for different groups (flat type) 
g_hdb4b  # wide table
# Out:
# flat_type REGION_C       SUBZONE_N    2 ROOM    3 ROOM    4 ROOM     5 ROOM
# 0               CR  ALEXANDRA HILL  290000.0  328000.0  700000.0   836944.0
# 1               CR        ALJUNIED  297500.0  380000.0  650000.0   852000.0
# 2               CR      ANAK BUKIT       NaN       NaN  805000.0  1050000.0
# 3               CR       BALESTIER       NaN  345000.0  704500.0   790000.0
# 4               CR       BENCOOLEN  328000.0  380000.0  788000.0        NaN
# ..             ...             ...       ...       ...       ...        ...
# 146             WR           WENYA       NaN       NaN  449000.0   518000.0
# 147             WR         YEW TEE       NaN       NaN  478444.0   540000.0
# 148             WR      YUHUA EAST       NaN  366500.0  465000.0   628000.0
# 149             WR      YUHUA WEST  302500.0  375250.0  482500.0   600000.0
# 150             WR          YUNNAN  280000.0  365000.0  460000.0   560000.0
#
# [151 rows x 6 columns]

# %%
for col in ftypes:
    #print(col)
    nan_count_col = g_hdb4b[col].isna().sum()
    print(col, nan_count_col)
# perhaps we should remove 2 room, 87 missing value is more than 50% of the subzones
# Out:
# 2 ROOM 87
# 3 ROOM 15
# 4 ROOM 4
# 5 ROOM 11

# %%
87/151  # 57.6%
# Out:
# 0.5761589403973509

# %%
g_hdb4c = g_hdb4b[['REGION_C', 'SUBZONE_N', '3 ROOM', '4 ROOM', '5 ROOM']]
g_hdb4c = g_hdb4c.dropna()
len(g_hdb4c)
# Out:
# 125

# %%
g_hdb4c  # the wide table
# Out:
# flat_type REGION_C       SUBZONE_N    3 ROOM    4 ROOM     5 ROOM
# 0               CR  ALEXANDRA HILL  328000.0  700000.0   836944.0
# 1               CR        ALJUNIED  380000.0  650000.0   852000.0
# 3               CR       BALESTIER  345000.0  704500.0   790000.0
# 5               CR       BENDEMEER  399500.0  839000.0  1023000.0
# 6               CR     BISHAN EAST  493000.0  635000.0   890000.0
# ..             ...             ...       ...       ...        ...
# 144             WR       TECK WHYE  378000.0  460000.0   575000.0
# 145             WR        TOH GUAN  381000.0  530888.0   708000.0
# 148             WR      YUHUA EAST  366500.0  465000.0   628000.0
# 149             WR      YUHUA WEST  375250.0  482500.0   600000.0
# 150             WR          YUNNAN  365000.0  460000.0   560000.0
#
# [125 rows x 5 columns]

# %% [markdown]
# let's make some plots

# %%
ftypes2 = ['3 ROOM', '4 ROOM', '5 ROOM']

fig, axg = plt.subplots(2, 3, figsize=(12, 8), sharex=False, sharey=True)
axs = axg.flatten()

for i, reg in enumerate(g_hdb4c['REGION_C'].unique()):
    ax = axs[i]
    tmp = g_hdb4c[g_hdb4c['REGION_C']==reg]
    #print(tmp)
    print(i, reg, len(tmp))
    for j, row in tmp.iterrows():
        #print(row)
        vs = [row[ft] for ft in ftypes2]
        #print(vs)
        ax.plot(list(range(3)), vs, c='grey', alpha=.3)
        #break
    tmp2 = tmp[ftypes2].median()
    print(tmp2)
    ax.plot(list(range(3)), tmp2, c='blue', marker='o')
    ax.set_title(reg)
    #break
for ax in axs:
    ax.set_xticks([0, 1, 2])
    ax.set_xticklabels(ftypes2)

axs[-1].axis('off')

plt.tight_layout()
# Out:
# 0 CR 45
# flat_type
# 3 ROOM    408000.0
# 4 ROOM    713444.0
# 5 ROOM    861500.0
# dtype: float64
# 1 ER 8
# flat_type
# 3 ROOM    389500.0
# 4 ROOM    563000.0
# 5 ROOM    688000.0
# dtype: float64
# 2 NER 26
# flat_type
# 3 ROOM    407500.0
# 4 ROOM    571500.0
# 5 ROOM    715000.0
# dtype: float64
# 3 NR 16
# flat_type
# 3 ROOM    411250.0
# 4 ROOM    498000.0
# 5 ROOM    595000.0
# dtype: float64
# 4 WR 30
# flat_type
# 3 ROOM    380500.0
# 4 ROOM    500000.0
# 5 ROOM    632500.0
# dtype: float64

# %%
g_hdb4c_long = g_hdb4c.melt(id_vars=['REGION_C', 'SUBZONE_N'])  # convert it back to long table
g_hdb4c_long = g_hdb4c_long.rename(columns={'value': 'resale_price'})
g_hdb4c_long
# Out:
#     REGION_C       SUBZONE_N flat_type  resale_price
# 0         CR  ALEXANDRA HILL    3 ROOM      328000.0
# 1         CR        ALJUNIED    3 ROOM      380000.0
# 2         CR       BALESTIER    3 ROOM      345000.0
# 3         CR       BENDEMEER    3 ROOM      399500.0
# 4         CR     BISHAN EAST    3 ROOM      493000.0
# ..       ...             ...       ...           ...
# 370       WR       TECK WHYE    5 ROOM      575000.0
# 371       WR        TOH GUAN    5 ROOM      708000.0
# 372       WR      YUHUA EAST    5 ROOM      628000.0
# 373       WR      YUHUA WEST    5 ROOM      600000.0
# 374       WR          YUNNAN    5 ROOM      560000.0
#
# [375 rows x 4 columns]

# %%
pg.mixed_anova(data=g_hdb4c_long, dv='resale_price', within='flat_type', subject='SUBZONE_N', between='REGION_C',)
# Out:
#         Source            SS  DF1  DF2            MS           F  \
# 0     REGION_C  1.797383e+12    4  120  4.493457e+11   21.694839
# 1    flat_type  6.975618e+12    2  240  3.487809e+12  542.605936
# 2  Interaction  5.828804e+11    8  240  7.286005e+10   11.334994
#
#           p-unc     p-GG-corr       np2       eps sphericity   W-spher  \
# 0  1.731484e-13           NaN  0.419671       NaN        NaN       NaN
# 1  8.935336e-90  5.985883e-68  0.818897  0.854165      False  0.829267
# 2  1.319473e-13           NaN  0.274223       NaN        NaN       NaN
#
#    p-spher
# 0      NaN
# 1  0.00001
# 2      NaN

# %%
mph = pg.pairwise_tests(data=g_hdb4c_long, dv='resale_price', between='REGION_C', within='flat_type', subject='SUBZONE_N',
                          parametric=True, marginal=True, alpha=0.05, alternative='two-sided', 
                          padjust='none', effsize='hedges', correction='auto', nan_policy='listwise', 
                          return_desc=False, interaction=True, within_first=True)
mph
# Out:
#                 Contrast flat_type       A       B Paired Parametric  \
# 0              flat_type         -  3 ROOM  4 ROOM   True       True
# 1              flat_type         -  3 ROOM  5 ROOM   True       True
# 2              flat_type         -  4 ROOM  5 ROOM   True       True
# 3               REGION_C         -      CR      ER  False       True
# 4               REGION_C         -      CR     NER  False       True
# 5               REGION_C         -      CR      NR  False       True
# 6               REGION_C         -      CR      WR  False       True
# 7               REGION_C         -      ER     NER  False       True
# 8               REGION_C         -      ER      NR  False       True
# 9               REGION_C         -      ER      WR  False       True
# 10              REGION_C         -     NER      NR  False       True
# 11              REGION_C         -     NER      WR  False       True
# 12              REGION_C         -      NR      WR  False       True
# 13  flat_type * REGION_C    3 ROOM      CR      ER  False       True
# 14  flat_type * REGION_C    3 ROOM      CR     NER  False       True
# 15  flat_type * REGION_C    3 ROOM      CR      NR  False       True
# 16  flat_type * REGION_C    3 ROOM      CR      WR  False       True
# 17  flat_type * REGION_C    3 ROOM      ER     NER  False       True
# 18  flat_type * REGION_C    3 ROOM      ER      NR  False       True
# 19  flat_type * REGION_C    3 ROOM      ER      WR  False       True
# 20  flat_type * REGION_C    3 ROOM     NER      NR  False       True
# 21  flat_type * REGION_C    3 ROOM     NER      WR  False       True
# 22  flat_type * REGION_C    3 ROOM      NR      WR  False       True
# 23  flat_type * REGION_C    4 ROOM      CR      ER  False       True
# 24  flat_type * REGION_C    4 ROOM      CR     NER  False       True
# 25  flat_type * REGION_C    4 ROOM      CR      NR  False       True
# 26  flat_type * REGION_C    4 ROOM      CR      WR  False       True
# 27  flat_type * REGION_C    4 ROOM      ER     NER  False       True
# 28  flat_type * REGION_C    4 ROOM      ER      NR  False       True
# 29  flat_type * REGION_C    4 ROOM      ER      WR  False       True
# 30  flat_type * REGION_C    4 ROOM     NER      NR  False       True
# 31  flat_type * REGION_C    4 ROOM     NER      WR  False       True
# 32  flat_type * REGION_C    4 ROOM      NR      WR  False       True
# 33  flat_type * REGION_C    5 ROOM      CR      ER  False       True
# 34  flat_type * REGION_C    5 ROOM      CR     NER  False       True
# 35  flat_type * REGION_C    5 ROOM      CR      NR  False       True
# 36  flat_type * REGION_C    5 ROOM      CR      WR  False       True
# 37  flat_type * REGION_C    5 ROOM      ER     NER  False       True
# 38  flat_type * REGION_C    5 ROOM      ER      NR  False       True
# 39  flat_type * REGION_C    5 ROOM      ER      WR  False       True
# 40  flat_type * REGION_C    5 ROOM     NER      NR  False       True
# 41  flat_type * REGION_C    5 ROOM     NER      WR  False       True
# 42  flat_type * REGION_C    5 ROOM      NR      WR  False       True
#
#             T         dof alternative         p-unc       BF10    hedges
# 0  -15.895738  124.000000   two-sided  1.051045e-31  2.918e+28 -1.672786
# 1  -24.938102  124.000000   two-sided  3.791171e-50  4.708e+46 -2.711672
# 2  -15.066078  124.000000   two-sided  8.536083e-30  3.844e+26 -0.896488
# 3    5.419548   25.782608   two-sided  1.144687e-05    6789.44  1.170566
# 4    5.188191   68.273477   two-sided  2.068298e-06   7059.712  1.077828
# 5    9.119660   58.838961   two-sided  7.401146e-13  6.553e+09  1.786777
# 6    6.801916   72.644025   two-sided  2.468995e-09  3.526e+06  1.448330
# 7   -1.059594   14.684420   two-sided  3.064481e-01      0.556 -0.367638
# 8    2.833456   13.029460   two-sided  1.407065e-02       5.23  1.221558
# 9    0.840834   16.865600   two-sided  4.122040e-01      0.474  0.257270
# 10   4.879311   38.881241   two-sided  1.843305e-05    979.224  1.407740
# 11   2.236484   53.921843   two-sided  2.947815e-02      2.071  0.583123
# 12  -2.256625   43.280138   two-sided  2.913533e-02      2.201 -0.592426
# 13   0.961031   14.978158   two-sided  3.517954e-01      0.502  0.257568
# 14   0.664554   64.722707   two-sided  5.086968e-01      0.304  0.133911
# 15   1.795779   58.902214   two-sided  7.765929e-02      1.058  0.343840
# 16   2.174227   63.542080   two-sided  3.341954e-02      1.794  0.439664
# 17  -0.595660    9.258105   two-sided  5.656778e-01      0.422 -0.282948
# 18   0.247917    9.189726   two-sided  8.096496e-01      0.397  0.125315
# 19   0.506569    8.889738   two-sided  6.247816e-01      0.402  0.243667
# 20   1.638280   37.615644   two-sided  1.097025e-01      0.885  0.481220
# 21   2.214500   52.625671   two-sided  3.114804e-02      1.992  0.585757
# 22   0.513398   37.376573   two-sided  6.106947e-01      0.338  0.145456
# 23   4.537082   20.777497   two-sided  1.842702e-04    467.031  1.053933
# 24   4.661276   68.749264   two-sided  1.492791e-05   1184.299  1.002449
# 25   8.738110   57.943980   two-sided  3.624426e-12  1.629e+09  1.636265
# 26   6.646456   70.662150   two-sided  5.283822e-09  1.907e+06  1.388723
# 27  -0.588327   15.054043   two-sided  5.650356e-01       0.42 -0.201706
# 28   2.436987    9.850425   two-sided  3.537110e-02      2.791  1.188178
# 29   0.934244   12.574947   two-sided  3.677715e-01      0.504  0.332738
# 30   4.002338   38.338715   two-sided  2.774936e-04      93.94  1.071160
# 31   1.932743   50.677002   two-sided  5.886564e-02       1.25  0.514796
# 32  -2.109652   43.972229   two-sided  4.061554e-02      1.726 -0.540422
# 33   7.105421   44.597165   two-sided  7.458145e-09  1.727e+06  1.306116
# 34   5.563427   68.958618   two-sided  4.686877e-07  2.673e+04  1.187169
# 35  10.286303   58.892034   two-sided  9.027812e-15  4.374e+11  2.010529
# 36   6.347066   71.119248   two-sided  1.795735e-08  5.909e+05  1.409104
# 37  -1.294816   27.799649   two-sided  2.060350e-01      0.678 -0.347060
# 38   4.368903   19.273653   two-sided  3.205882e-04     92.729  1.619674
# 39   0.417929   34.163532   two-sided  6.786145e-01      0.391  0.097267
# 40   5.100282   39.980415   two-sided  8.606565e-06   1819.771  1.427027
# 41   1.418833   53.044651   two-sided  1.617971e-01      0.622  0.367435
# 42  -2.898511   43.530137   two-sided  5.851653e-03      7.468 -0.721356

# %%
mph[mph['p-unc']>.05]
# Out:
#                 Contrast flat_type    A    B Paired Parametric         T  \
# 7               REGION_C         -   ER  NER  False       True -1.059594
# 9               REGION_C         -   ER   WR  False       True  0.840834
# 13  flat_type * REGION_C    3 ROOM   CR   ER  False       True  0.961031
# 14  flat_type * REGION_C    3 ROOM   CR  NER  False       True  0.664554
# 15  flat_type * REGION_C    3 ROOM   CR   NR  False       True  1.795779
# 17  flat_type * REGION_C    3 ROOM   ER  NER  False       True -0.595660
# 18  flat_type * REGION_C    3 ROOM   ER   NR  False       True  0.247917
# 19  flat_type * REGION_C    3 ROOM   ER   WR  False       True  0.506569
# 20  flat_type * REGION_C    3 ROOM  NER   NR  False       True  1.638280
# 22  flat_type * REGION_C    3 ROOM   NR   WR  False       True  0.513398
# 27  flat_type * REGION_C    4 ROOM   ER  NER  False       True -0.588327
# 29  flat_type * REGION_C    4 ROOM   ER   WR  False       True  0.934244
# 31  flat_type * REGION_C    4 ROOM  NER   WR  False       True  1.932743
# 37  flat_type * REGION_C    5 ROOM   ER  NER  False       True -1.294816
# 39  flat_type * REGION_C    5 ROOM   ER   WR  False       True  0.417929
# 41  flat_type * REGION_C    5 ROOM  NER   WR  False       True  1.418833
#
#           dof alternative     p-unc   BF10    hedges
# 7   14.684420   two-sided  0.306448  0.556 -0.367638
# 9   16.865600   two-sided  0.412204  0.474  0.257270
# 13  14.978158   two-sided  0.351795  0.502  0.257568
# 14  64.722707   two-sided  0.508697  0.304  0.133911
# 15  58.902214   two-sided  0.077659  1.058  0.343840
# 17   9.258105   two-sided  0.565678  0.422 -0.282948
# 18   9.189726   two-sided  0.809650  0.397  0.125315
# 19   8.889738   two-sided  0.624782  0.402  0.243667
# 20  37.615644   two-sided  0.109703  0.885  0.481220
# 22  37.376573   two-sided  0.610695  0.338  0.145456
# 27  15.054043   two-sided  0.565036   0.42 -0.201706
# 29  12.574947   two-sided  0.367772  0.504  0.332738
# 31  50.677002   two-sided  0.058866   1.25  0.514796
# 37  27.799649   two-sided  0.206035  0.678 -0.347060
# 39  34.163532   two-sided  0.678614  0.391  0.097267
# 41  53.044651   two-sided  0.161797  0.622  0.367435

# %%
mph[mph['p-unc']<=.05]
# Out:
#                 Contrast flat_type       A       B Paired Parametric  \
# 0              flat_type         -  3 ROOM  4 ROOM   True       True
# 1              flat_type         -  3 ROOM  5 ROOM   True       True
# 2              flat_type         -  4 ROOM  5 ROOM   True       True
# 3               REGION_C         -      CR      ER  False       True
# 4               REGION_C         -      CR     NER  False       True
# 5               REGION_C         -      CR      NR  False       True
# 6               REGION_C         -      CR      WR  False       True
# 8               REGION_C         -      ER      NR  False       True
# 10              REGION_C         -     NER      NR  False       True
# 11              REGION_C         -     NER      WR  False       True
# 12              REGION_C         -      NR      WR  False       True
# 16  flat_type * REGION_C    3 ROOM      CR      WR  False       True
# 21  flat_type * REGION_C    3 ROOM     NER      WR  False       True
# 23  flat_type * REGION_C    4 ROOM      CR      ER  False       True
# 24  flat_type * REGION_C    4 ROOM      CR     NER  False       True
# 25  flat_type * REGION_C    4 ROOM      CR      NR  False       True
# 26  flat_type * REGION_C    4 ROOM      CR      WR  False       True
# 28  flat_type * REGION_C    4 ROOM      ER      NR  False       True
# 30  flat_type * REGION_C    4 ROOM     NER      NR  False       True
# 32  flat_type * REGION_C    4 ROOM      NR      WR  False       True
# 33  flat_type * REGION_C    5 ROOM      CR      ER  False       True
# 34  flat_type * REGION_C    5 ROOM      CR     NER  False       True
# 35  flat_type * REGION_C    5 ROOM      CR      NR  False       True
# 36  flat_type * REGION_C    5 ROOM      CR      WR  False       True
# 38  flat_type * REGION_C    5 ROOM      ER      NR  False       True
# 40  flat_type * REGION_C    5 ROOM     NER      NR  False       True
# 42  flat_type * REGION_C    5 ROOM      NR      WR  False       True
#
#             T         dof alternative         p-unc       BF10    hedges
# 0  -15.895738  124.000000   two-sided  1.051045e-31  2.918e+28 -1.672786
# 1  -24.938102  124.000000   two-sided  3.791171e-50  4.708e+46 -2.711672
# 2  -15.066078  124.000000   two-sided  8.536083e-30  3.844e+26 -0.896488
# 3    5.419548   25.782608   two-sided  1.144687e-05    6789.44  1.170566
# 4    5.188191   68.273477   two-sided  2.068298e-06   7059.712  1.077828
# 5    9.119660   58.838961   two-sided  7.401146e-13  6.553e+09  1.786777
# 6    6.801916   72.644025   two-sided  2.468995e-09  3.526e+06  1.448330
# 8    2.833456   13.029460   two-sided  1.407065e-02       5.23  1.221558
# 10   4.879311   38.881241   two-sided  1.843305e-05    979.224  1.407740
# 11   2.236484   53.921843   two-sided  2.947815e-02      2.071  0.583123
# 12  -2.256625   43.280138   two-sided  2.913533e-02      2.201 -0.592426
# 16   2.174227   63.542080   two-sided  3.341954e-02      1.794  0.439664
# 21   2.214500   52.625671   two-sided  3.114804e-02      1.992  0.585757
# 23   4.537082   20.777497   two-sided  1.842702e-04    467.031  1.053933
# 24   4.661276   68.749264   two-sided  1.492791e-05   1184.299  1.002449
# 25   8.738110   57.943980   two-sided  3.624426e-12  1.629e+09  1.636265
# 26   6.646456   70.662150   two-sided  5.283822e-09  1.907e+06  1.388723
# 28   2.436987    9.850425   two-sided  3.537110e-02      2.791  1.188178
# 30   4.002338   38.338715   two-sided  2.774936e-04      93.94  1.071160
# 32  -2.109652   43.972229   two-sided  4.061554e-02      1.726 -0.540422
# 33   7.105421   44.597165   two-sided  7.458145e-09  1.727e+06  1.306116
# 34   5.563427   68.958618   two-sided  4.686877e-07  2.673e+04  1.187169
# 35  10.286303   58.892034   two-sided  9.027812e-15  4.374e+11  2.010529
# 36   6.347066   71.119248   two-sided  1.795735e-08  5.909e+05  1.409104
# 38   4.368903   19.273653   two-sided  3.205882e-04     92.729  1.619674
# 40   5.100282   39.980415   two-sided  8.606565e-06   1819.771  1.427027
# 42  -2.898511   43.530137   two-sided  5.851653e-03      7.468 -0.721356

# %% [markdown]
# 3 parts:
# - the within group result: Contrast==flat_type
#     - 3 room < 4 room < 5 room, which are expected
# - the between group result: Contrast==REGION_C
#     - CR > all other regions
#     - ER > NR
#     - NER > NR and WR
#     - NR > WR
# - the interaction: Contrast==flat_type * REGION_C
#     - this examine if there is differences on "regional-relationship or regional-differences" between flat types
#     - 4 rooms and 5 rooms are same, but 3 rooms have less significant result

# %%
mph2 = pg.pairwise_tests(data=g_hdb4c_long, dv='resale_price', between='REGION_C', within='flat_type', subject='SUBZONE_N',
                          parametric=True, marginal=True, alpha=0.05, alternative='two-sided', 
                          padjust='none', effsize='hedges', correction='auto', nan_policy='listwise', 
                          return_desc=False, interaction=True, within_first=False)
mph2
# Out:
#                 Contrast REGION_C       A       B Paired Parametric  \
# 0               REGION_C        -      CR      ER  False       True
# 1               REGION_C        -      CR     NER  False       True
# 2               REGION_C        -      CR      NR  False       True
# 3               REGION_C        -      CR      WR  False       True
# 4               REGION_C        -      ER     NER  False       True
# 5               REGION_C        -      ER      NR  False       True
# 6               REGION_C        -      ER      WR  False       True
# 7               REGION_C        -     NER      NR  False       True
# 8               REGION_C        -     NER      WR  False       True
# 9               REGION_C        -      NR      WR  False       True
# 10             flat_type        -  3 ROOM  4 ROOM   True       True
# 11             flat_type        -  3 ROOM  5 ROOM   True       True
# 12             flat_type        -  4 ROOM  5 ROOM   True       True
# 13  REGION_C * flat_type       CR  3 ROOM  4 ROOM   True       True
# 14  REGION_C * flat_type       CR  3 ROOM  5 ROOM   True       True
# 15  REGION_C * flat_type       CR  4 ROOM  5 ROOM   True       True
# 16  REGION_C * flat_type       ER  3 ROOM  4 ROOM   True       True
# 17  REGION_C * flat_type       ER  3 ROOM  5 ROOM   True       True
# 18  REGION_C * flat_type       ER  4 ROOM  5 ROOM   True       True
# 19  REGION_C * flat_type      NER  3 ROOM  4 ROOM   True       True
# 20  REGION_C * flat_type      NER  3 ROOM  5 ROOM   True       True
# 21  REGION_C * flat_type      NER  4 ROOM  5 ROOM   True       True
# 22  REGION_C * flat_type       NR  3 ROOM  4 ROOM   True       True
# 23  REGION_C * flat_type       NR  3 ROOM  5 ROOM   True       True
# 24  REGION_C * flat_type       NR  4 ROOM  5 ROOM   True       True
# 25  REGION_C * flat_type       WR  3 ROOM  4 ROOM   True       True
# 26  REGION_C * flat_type       WR  3 ROOM  5 ROOM   True       True
# 27  REGION_C * flat_type       WR  4 ROOM  5 ROOM   True       True
#
#             T         dof alternative         p-unc       BF10    hedges
# 0    5.419548   25.782608   two-sided  1.144687e-05    6789.44  1.170566
# 1    5.188191   68.273477   two-sided  2.068298e-06   7059.712  1.077828
# 2    9.119660   58.838961   two-sided  7.401146e-13  6.553e+09  1.786777
# 3    6.801916   72.644025   two-sided  2.468995e-09  3.526e+06  1.448330
# 4   -1.059594   14.684420   two-sided  3.064481e-01      0.556 -0.367638
# 5    2.833456   13.029460   two-sided  1.407065e-02       5.23  1.221558
# 6    0.840834   16.865600   two-sided  4.122040e-01      0.474  0.257270
# 7    4.879311   38.881241   two-sided  1.843305e-05    979.224  1.407740
# 8    2.236484   53.921843   two-sided  2.947815e-02      2.071  0.583123
# 9   -2.256625   43.280138   two-sided  2.913533e-02      2.201 -0.592426
# 10 -15.895738  124.000000   two-sided  1.051045e-31  2.918e+28 -1.672786
# 11 -24.938102  124.000000   two-sided  3.791171e-50  4.708e+46 -2.711672
# 12 -15.066078  124.000000   two-sided  8.536083e-30  3.844e+26 -0.896488
# 13 -12.615093   44.000000   two-sided  3.255457e-16  1.902e+13 -2.152141
# 14 -19.571138   44.000000   two-sided  2.433143e-23  1.545e+20 -3.350187
# 15  -7.408653   44.000000   two-sided  2.891267e-09  4.125e+06 -0.948101
# 16  -6.593719    7.000000   two-sided  3.060895e-04    108.611 -2.151216
# 17 -10.412026    7.000000   two-sided  1.638450e-05   1242.664 -5.053157
# 18  -5.220792    7.000000   two-sided  1.224741e-03     34.967 -1.925817
# 19  -7.895578   25.000000   two-sided  2.983211e-08   4.65e+05 -2.108601
# 20 -14.562376   25.000000   two-sided  1.021899e-13  6.714e+10 -4.073552
# 21  -7.878578   25.000000   two-sided  3.101842e-08  4.484e+05 -1.379911
# 22 -17.634393   15.000000   two-sided  1.938655e-11  3.789e+08 -2.181734
# 23 -16.896179   15.000000   two-sided  3.576896e-11  2.148e+08 -4.161981
# 24 -11.259912   15.000000   two-sided  1.026616e-08  1.155e+06 -2.004345
# 25  -8.919932   29.000000   two-sided  8.255921e-10   1.36e+07 -2.005677
# 26 -13.055841   29.000000   two-sided  1.137055e-13  6.334e+10 -3.069490
# 27  -9.233557   29.000000   two-sided  3.902180e-10   2.76e+07 -1.318485

# %%
mph2[mph2['p-unc']>.05]
# Out:
#    Contrast REGION_C   A    B Paired Parametric         T       dof  \
# 4  REGION_C        -  ER  NER  False       True -1.059594  14.68442
# 6  REGION_C        -  ER   WR  False       True  0.840834  16.86560
#
#   alternative     p-unc   BF10    hedges
# 4   two-sided  0.306448  0.556 -0.367638
# 6   two-sided  0.412204  0.474  0.257270

# %% [markdown]
# the interaction effect:
# are there any differences on the "flat types relationships" between regions---they were all significant and same accross regions
